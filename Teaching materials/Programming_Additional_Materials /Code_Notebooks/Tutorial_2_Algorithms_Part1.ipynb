# %% [markdown]
# # Tutorial 2: Algorithms & Problem Solving
#
# ## 📋 Learning Outcomes
#
# By the end of this tutorial, you will be able to:
# 1. **Demonstrate understanding of algorithms** and their applications (LO 2)
# 2. **Explain sequential nature** of problem solving (LO 5)
# 3. **Summarize structured programming concepts** including pseudo-code (LO 6)
# 4. Apply algorithmic thinking to ML problems
#
# ## 🎯 What You'll Learn
# - What algorithms are and why they matter
# - How to design algorithms using pseudocode
# - How to create flowcharts
# - Sequential problem-solving steps
# - Building your first prediction algorithm
#
# ---

# %% [markdown]
# ## Part 1: Understanding Algorithms
#
# ### 🤔 What is an Algorithm?
#
# An **algorithm** is:
# - A step-by-step procedure to solve a problem
# - A recipe for accomplishing a task
# - A finite sequence of well-defined instructions
#
# ### Real-World Algorithm Examples
#
# #### Making Tea (Everyday Algorithm)
# 1. Boil water
# 2. Place tea bag in cup
# 3. Pour hot water into cup
# 4. Wait 3-5 minutes
# 5. Remove tea bag
# 6. Add milk and sugar (optional)
# 7. Stir
# 8. Enjoy!
#
# #### Finding a Name in a Phone Book
# 1. Open book to middle
# 2. If name is on this page → Done!
# 3. If name comes before → Search left half
# 4. If name comes after → Search right half
# 5. Repeat until found
#
# This is called **Binary Search** - a famous algorithm!
#
# ### Properties of Good Algorithms
#
# 1. **Clear Instructions**: Each step is unambiguous
# 2. **Finite**: Will eventually complete
# 3. **Well-defined Input**: Knows what data it needs
# 4. **Well-defined Output**: Produces expected result
# 5. **Effective**: Each step can actually be performed
#
# Let's demonstrate a simple algorithm in code:

# %%
# Algorithm: Find the largest of three numbers

print("=== Finding Largest Number ===")
print()

# Input
num1 = 45
num2 = 67
num3 = 23

print("Numbers:", num1, num2, num3)
print()

# Algorithm steps
print("Algorithm Steps:")
print("1. Assume first number is largest")
largest = num1
print(f"   Currently largest = {largest}")
print()

print("2. Compare with second number")
if num2 > largest:
    largest = num2
    print(f"   Found larger: {largest}")
else:
    print(f"   No change: {largest} still largest")
print()

print("3. Compare with third number")
if num3 > largest:
    largest = num3
    print(f"   Found larger: {largest}")
else:
    print(f"   No change: {largest} still largest")
print()

# Output
print(f"Result: Largest number is {largest}")
print()
print("This algorithm works for ANY three numbers!")

# %% [markdown]
# ### 🎯 Algorithms in Machine Learning
#
# ML is full of algorithms!
#
# **Common ML Algorithms:**
# - **Linear Regression**: Find best-fit line through data
# - **Decision Trees**: Make decisions based on questions
# - **K-Nearest Neighbors**: Find similar examples
# - **Neural Networks**: Learn complex patterns
#
# Today we'll build a simple ML-style algorithm!

# %% [markdown]
# ---
#
# ## Part 2: Sequential Problem Solving
#
# ### 📝 The Development Cycle
#
# Professional software development follows a cycle:
#
# ```
# 1. UNDERSTAND THE PROBLEM
#    ↓
# 2. DESIGN THE SOLUTION (Algorithm/Pseudocode)
#    ↓
# 3. CODE THE SOLUTION (Programming)
#    ↓
# 4. TEST THE SOLUTION (Debugging)
#    ↓
# 5. REFINE AND IMPROVE
#    ↓
# (Repeat as needed)
# ```
#
# ### Step 1: Understand the Problem
#
# **Questions to Ask:**
# - What are the inputs?
# - What are the outputs?
# - What are the requirements?
# - What are the constraints?
# - Are there edge cases?
#
# ### Example Problem: Student Grade Calculator
#
# **Requirements:**
# - **Input**: Student's exam scores (0-100)
# - **Output**: Average score and grade category
# - **Rules**:
#   - Distinction: 80+
#   - Merit: 65-79
#   - Pass: 50-64
#   - Fail: Below 50
#
# Let's solve this sequentially:

# %%
# Sequential Problem Solving: Grade Calculator

print("=== Student Grade Calculator ===")
print()

# STEP 1: Define the problem
print("STEP 1: Problem Definition")
print("Calculate average and grade from 3 exam scores")
print()

# STEP 2: Get inputs
print("STEP 2: Input Data")
exam1 = 75
exam2 = 82
exam3 = 68
print(f"Exam 1: {exam1}")
print(f"Exam 2: {exam2}")
print(f"Exam 3: {exam3}")
print()

# STEP 3: Calculate average
print("STEP 3: Calculate Average")
total = exam1 + exam2 + exam3
average = total / 3
print(f"Total: {total}")
print(f"Average: {average:.2f}")
print()

# STEP 4: Determine grade
print("STEP 4: Determine Grade")
if average >= 80:
    grade = "Distinction"
elif average >= 65:
    grade = "Merit"
elif average >= 50:
    grade = "Pass"
else:
    grade = "Fail"
print(f"Grade: {grade}")
print()

# STEP 5: Output results
print("STEP 5: Final Results")
print(f"Final Average: {average:.2f}%")
print(f"Grade Category: {grade}")
print()
print("Sequential solving: One step at a time!")
